# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
np.random.seed(sum(map(ord, "aesthetics")))

# %% [markdown]
# Simple function to create offset sine waves

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %% [markdown]
# plot with matplotlib defaults.

# %%
sinplot()

# %% [markdown]
# Ok this is quite cool, I think i'm using jupyter notebooks from now on. Specially because their integration with
# pycharm is great.

# %%
import seaborn as sns

# %%
sinplot()

# %% [markdown]
# This is the defaults of seaborn. Personally I think the first one is cleaner. I like plots without clutter but that can be changed with some settings.

# %%
sns.set_style("white")
sinplot()
#remove top and side lines from plot
sns.despine()

# %% [markdown]
# Much better. For more information on how to customise plots see the [documentation](http://seaborn.pydata.org/tutorial/aesthetics.html#aesthetics-tutorial)
